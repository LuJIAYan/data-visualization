# %% [markdown]
# # 柱状图

# %%
import pandas as pd
df =pd.read_csv("themes2.csv",encoding='gbk')
df
# Out:
#                                                    title month  years  \
# 0              Ken Robinson: Do schools kill creativity?   Feb   2006
# 1              Ken Robinson: Do schools kill creativity?   Feb   2006
# 2              Ken Robinson: Do schools kill creativity?   Feb   2006
# 3              Ken Robinson: Do schools kill creativity?   Feb   2006
# 4              Ken Robinson: Do schools kill creativity?   Feb   2006
# 5              Ken Robinson: Do schools kill creativity?   Feb   2006
# 6              Ken Robinson: Do schools kill creativity?   Feb   2006
# 7                   Al Gore: Averting the climate crisis   Feb   2006
# 8                   Al Gore: Averting the climate crisis   Feb   2006
# 9                   Al Gore: Averting the climate crisis   Feb   2006
# 10                  Al Gore: Averting the climate crisis   Feb   2006
# 11                  Al Gore: Averting the climate crisis   Feb   2006
# ...

# %%
print(list(df["themes"].unique()))
# Out:
# ['children', 'creativity', 'culture', 'dance', 'education', 'parenting', 'teaching', 'alternative energy', 'cars', 'climate change', 'environment', 'global issues', 'science', 'sustainability', 'technology', 'computers', 'entertainment', 'interface design', 'media', 'music', 'performance', 'simplicity', 'software', 'MacArthur grant', 'activism', 'business', 'cities', 'green', 'inequality', 'politics', 'pollution', 'Africa', 'Asia', 'Google', 'demo', 'economics', 'global development', 'health', 'math', 'statistics', 'visualizations', 'goal-setting', 'motivation', 'potential', 'psychology', 'Christianity', 'God', 'atheism', 'comedy', 'humor', 'religion', 'storytelling', 'architecture', 'collaboration', 'design', 'library', 'TED Brain Trust', 'brain', 'cognitive science', 'consciousness', 'evolution', 'philosophy', 'happiness', 'leadership', 'philanthropy', 'disaster relief', 'invention', 'open-source', 'TED Prize', 'art', 'film', 'movies', 'peace', 'social change', 'disease', 'ebola', 
# ...

# %%
print(list(df.comments))
# Out:
# [4553, 4553, 4553, 4553, 4553, 4553, 4553, 265, 265, 265, 265, 265, 265, 265, 265, 265, 124, 124, 124, 124, 124, 124, 124, 124, 124, 200, 200, 200, 200, 200, 200, 200, 200, 200, 593, 593, 593, 593, 593, 593, 593, 593, 593, 593, 593, 672, 672, 672, 672, 672, 672, 672, 919, 919, 919, 919, 919, 919, 919, 919, 919, 46, 46, 46, 46, 46, 852, 852, 852, 852, 852, 852, 852, 852, 852, 900, 900, 900, 900, 900, 900, 900, 900, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 71, 71, 71, 71, 71, 71, 71, 71, 242, 242, 242, 242, 99, 99, 99, 99, 99, 99, 99, 99, 325, 325, 325, 325, 325, 325, 305, 305, 305, 305, 305, 305, 88, 88, 88, 88, 88, 88, 88, 88, 163, 163, 163, 163, 163, 163, 163, 163, 163, 84, 84, 84, 84, 84, 84, 84, 84, 108, 108, 108, 108, 108, 108, 108, 185, 185, 185, 185, 185, 185, 185, 185, 185, 185, 50, 50, 50, 50, 50, 50, 50, 50, 556, 556, 556, 556, 556, 556, 556, 556, 117, 117, 117, 117, 117, 117, 117, 117, 117, 184, 184, 184, 184, 184, 184, 184, 184, 184, 
# ...

# %%
df["views"].unique().tolist()
# Out:
# [47227110,
#  3200520,
#  1636292,
#  1697550,
#  12005869,
#  20685401,
#  3769987,
#  967741,
#  2567958,
#  3095993,
#  1211416,
#  387877,
#  693341,
#  4531020,
#  358304,
#  2702470,
#  1628912,
#  1415724,
#  1074081,
#  1106561,
#  966439,
#  6141440,
#  518624,
#  9260764,
#  1131864,
#  1096862,
#  2885999,
#  2863214,
#  7023562,
#  14689301,
#  10000702,
#  1030267,
#  3277740,
#  503517,
#  705389,
#  580891,
#  809226,
#  2028451,
#  745231,
#  718649,
#  975107,
#  382996,
#  1053758,
#  5364639,
#  2434344,
#  1536873,
#  904215,
#  10841210,
#  1813665,
#  2299265,
#  673036,
#  1391142,
#  2532851,
#  882034,
#  2121177,
#  1090180,
#  684519,
#  1409327,
#  3051507,
#  978825,
#  442553,
#  691814,
#  2441805,
#  849859,
#  1335732,
#  1262674,
#  1663001,
#  5570544,
#  1520908,
#  2138907,
#  680134,
#  690928,
#  1762302,
#  1392010,
#  660909,
#  867495,
#  395769,
#  761930,
#  1149090,
#  762264,
#  1920434,
#  560904,
#  606311,
#  2197377,
#  1697185,
# ...

# %%
df["themes"].value_counts().tolist()
# Out:
# [727,
#  567,
#  501,
#  486,
#  450,
#  418,
#  348,
#  299,
#  236,
#  229,
#  224,
#  221,
#  218,
#  195,
#  191,
#  189,
#  189,
#  182,
#  174,
#  165,
#  164,
#  162,
#  158,
#  157,
#  153,
#  148,
#  146,
#  143,
#  143,
#  140,
#  140,
#  132,
#  128,
#  123,
#  122,
#  120,
#  117,
#  117,
#  116,
#  113,
#  113,
#  111,
#  111,
#  111,
#  109,
#  105,
#  105,
#  100,
#  96,
#  94,
#  94,
#  93,
#  92,
#  92,
#  89,
#  87,
#  84,
#  83,
#  82,
#  80,
#  80,
#  79,
#  77,
#  75,
#  73,
#  73,
#  73,
#  72,
#  71,
#  71,
#  69,
#  68,
#  68,
#  67,
#  67,
#  65,
#  64,
#  64,
#  64,
#  63,
#  63,
#  62,
#  62,
#  60,
#  59,
#  59,
#  59,
#  59,
#  58,
#  57,
#  57,
#  56,
#  54,
#  54,
#  54,
#  53,
#  53,
#  53,
#  52,
#  52,
#  52,
#  51,
#  51,
#  50,
#  50,
#  50,
#  50,
#  49,
#  49,
#  48,
#  48,
#  48,
#  48,
#  47,
#  47,
#  47,
#  46,
#  45,
#  44,
#  44,
#  44,
#  43,
#  43,
#  43,
#  43,
#  43,
#  42,
#  42,
#  41,
#  40,
#  39,
#  39,
#  39,
#  38,
#  38,
#  38,
# ...

# %%
a=df['themes'].value_counts()
a
# Out:
# technology           727
# science              567
# global issues        501
# culture              486
# TEDx                 450
# design               418
# business             348
# entertainment        299
# health               236
# innovation           229
# society              224
# art                  221
# social change        218
# future               195
# communication        191
# biology              189
# creativity           189
# humanity             182
# collaboration        174
# environment          165
# economics            164
# medicine             162
# brain                158
# activism             157
# education            153
# community            148
# history              146
# TED Fellows          143
# children             143
# music                140
#                     ...
# jazz                   4
# vulnerability          4
# ants                   4
# CRISPR                 4
# urban                  4
# microfinance           4
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    a = (
        Bar()
        .add_xaxis(df["themes"].unique().tolist())
        .add_yaxis("浏览量", list(df.views) ,color=Faker.rand_color())
        .add_yaxis("评论数", list(df.comments) ,color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="TED演讲视频各主题浏览量及评论数数"),
            datazoom_opts=[opts.DataZoomOpts()],  
        )
    )
       
    return a

# %%
a= bar_base()
a.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="96db2adf172f45c692e81e90e38962a3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_96db2adf172f45c692e81e90e38962a3 = echarts.init(
#                     document.getElementById('96db2adf172f45c692e81e90e38962a3'), 'white', {renderer: 'canvas'});
#                 var option_96db2adf172f45c692e81e90e38962a3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#6950a1",
#         "#6d8346",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.charts import Scatter

    
def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(list(df.themes))
        .add_yaxis("评论数", list(df.comments),color=Faker.rand_color())
        .add_yaxis("浏览量", list(df.views),color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-东南亚各国参观（visited）数"),
            datazoom_opts=[opts.DataZoomOpts()],  
        )
    )
    return c

# %%
c = bar_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1740c05b7ddf457a89522db61b5ece15" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1740c05b7ddf457a89522db61b5ece15 = echarts.init(
#                     document.getElementById('1740c05b7ddf457a89522db61b5ece15'), 'white', {renderer: 'canvas'});
#                 var option_1740c05b7ddf457a89522db61b5ece15 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#749f83",
#         "#d48265",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    a = (
        Bar()
        .add_xaxis(df["themes"].unique().tolist())
        .add_yaxis("个数", df["themes"].value_counts().tolist() ,color=Faker.rand_color())

        .set_global_opts(
            title_opts=opts.TitleOpts(title="TED演讲视频各主题浏览量及评论数数"),
            datazoom_opts=[opts.DataZoomOpts()],  
        )
    )
       
    return a

# %%
a = bar_base()
a.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f3ccb3ffaa384eb2b8e6d91a0c5f8510" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f3ccb3ffaa384eb2b8e6d91a0c5f8510 = echarts.init(
#                     document.getElementById('f3ccb3ffaa384eb2b8e6d91a0c5f8510'), 'white', {renderer: 'canvas'});
#                 var option_f3ccb3ffaa384eb2b8e6d91a0c5f8510 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#2f4554",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...
